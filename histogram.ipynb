# %%
import numpy as np
import matplotlib.pyplot as plt

age = np.random.randint(1,100,500)
age

bin = [0,18,30,50,70,90,100]

plt.hist(age,ec='k')
# plt.hist(age,bin,color='green')
# Out:
# (array([46., 61., 38., 49., 51., 36., 43., 61., 57., 58.]),
#  array([ 1. , 10.8, 20.6, 30.4, 40.2, 50. , 59.8, 69.6, 79.4, 89.2, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
var1 = [25,41,63,96,45]
var2 = [45,63,65,25,75]

plt.scatter(var1,var2)
plt.xlabel('var-1')
plt.ylabel('var-2')
# Out:
# Text(0, 0.5, 'var-2')

# %%
import pandas as pd

df = pd.read_csv("E:\\Internship\\Used_Bikes.csv")
df.shape

df.drop_duplicates(inplace=True)
df.shape

plt.scatter(df['kms_driven'],df['price'])
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
ktm = df[df['brand'] == "KTM"]
ktm['price'].sort_values().head(10)
plt.boxplot(ktm['price'])
# plt.show()
ktm['bike_name'].shape
# Out:
# (375,)

# %%
plt.scatter(df['power'],df['price'])

# %%
country_population = [450,730,900,450,800]
country_name = ['Japan','Bangladesh','India','Nepal','China']
explosion = [0.2,0,0,0,0.1]
plt.figure(figsize=(6,6))
plt.pie(country_population,labels=country_name,autopct="%2.2f",explode=explosion,shadow=True,wedgeprops={'ec':'black','lw':1})
plt.savefig('pie_chart_population')
plt.show()
