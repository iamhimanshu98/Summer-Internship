# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
print('libraries impprted')

brand = ['samsung','apple','vivo']
total = [12,8,10]

plt.bar(brand,total)
# Out:
# libraries impprted
# <BarContainer object of 3 artists>

# %%
df = pd.read_csv("E:\\Internship\\Used_Bikes.csv")
df.drop_duplicates(inplace=True)
df.shape

# brand_name = list(df['brand'].value_counts().keys())
# total_bikes = list(df['brand'].value_counts().values)
# plt.figure(figsize=(8,5))
# plt.xticks(rotation=75)
# plt.bar(brand_name,total_bikes)

df = pd.DataFrame({'Brand' : brand, 'Total' : total})

sb.barplot(y='Total',x='Brand',data=df)
# Out:
# <Axes: xlabel='Brand', ylabel='Total'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sb.load_dataset('tips')
df.head()

# plt.scatter(df['tip'],df['total_bill'])
# sns.scatterplot(x='tip',y='total_bill',data=df,hue='sex',style='smoker')
sns.relplot(x='tip',y='total_bill',data=df,col='day',hue='time')
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='boxen')

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='violin')

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='strip')

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='swarm')

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='bar')

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='point')
